# %% [markdown]
# <a href="https://colab.research.google.com/github/voirlarel/technology_ETL/blob/main/tech_ETL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from datetime import datetime

# Настройка отображения
plt.style.use('ggplot')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

print("ЧАСТЬ 1: ОЧИСТКА НАБОРА ДАННЫХ DATA.CSV")
# Out:
# ЧАСТЬ 1: ОЧИСТКА НАБОРА ДАННЫХ DATA.CSV

# %%
# Загрузка первых 1000 записей из data.csv
# Предполагаем, что файл data.csv находится в той же директории
try:
    url = "https://raw.githubusercontent.com/voirlarel/technology_ETL/main/data.csv"
    df = pd.read_csv(url)
    print(f"Загружено {df.shape[0]} строк и {df.shape[1]} столбцов")
except FileNotFoundError:
    print("Файл data.csv не найден.")
# Out:
# Загружено 1000 строк и 292 столбцов
